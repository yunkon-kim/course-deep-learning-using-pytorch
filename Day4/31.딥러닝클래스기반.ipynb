# %%
import torch
from torch.optim import Adam
from torch.nn import Linear, MSELoss, Sequential, Sigmoid, Softmax, ReLU, Module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.nn.functional as F
import seaborn as sb

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.datasets import load_iris
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, accuracy_score, precision_score
from sklearn.model_selection import train_test_split

import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
x_data =[[0,0],[0,1],[1,0],[1,1]]
y_data =[[0],[1],[1],[0]]

# %%
x = torch.FloatTensor(x_data)
y = torch.FloatTensor(y_data)

# %%
class Test:
    def __init__(self): # 객체생성시 자동호출되는 함수
        print('생성자함수')
        self.a = 100
    def setA(self, a):
        self.a = a
    def getA(self):
        return self.a

# %%
obj = Test()
# Out:
# 생성자함수

# %%
obj.getA()
# Out:
# 100

# %%
obj.setA(200)
obj.getA()
# Out:
# 200

# %%
class XORModel(Module):
    def __init__(self):
        super().__init__() # 초기화작업
        self.nn1 = Linear(2, 20)
        self.sig1 = Sigmoid()
        self.nn2 = Linear(20, 1)
        self.sig2 = Sigmoid()
    
    def forward(self, x):
        print('forward call')
#         x = self.nn1.forward(x)
        x = self.nn1(x) # matmul(x, w1) + b1  w1:2x20
        x = self.sig1(x) # 1/1+e^-z
        x = self.nn2(x) # matmul(x, w2) + b2  w2:20x1
        x = self.sig2(x)
        return x

# %%
model = XORModel()
loss_fn = torch.nn.BCELoss()
hist=[]
optimizer = Adam(model.parameters(), lr=0.01)
for epoch in range(1000):
    optimizer.zero_grad()
    hx = model.forward(x) 
    # z = torch.matmul(x,w)+b
    # hx = Softmax(z)
    cost = loss_fn(hx,y)
    cost.backward()
    optimizer.step()
    print('------------------------------')
    pred = (hx > 0.5) + 0
    print('정확도', torch.mean((y==pred).type(torch.float32)) )
    print(epoch, cost.item())
    hist.append(cost.item())
# Out:
# forward call
# ------------------------------
# 정확도 tensor(0.2500)
# 0 0.6942101716995239
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 1 0.6934955716133118
# forward call
# ------------------------------
# 정확도 tensor(0.7500)
# 2 0.6937829852104187
# forward call
# ------------------------------
# 정확도 tensor(0.7500)
# 3 0.6932567358016968
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 4 0.6928690671920776
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 5 0.6928923726081848
# forward call
# ------------------------------
# 정확도 tensor(0.2500)
# 6 0.6928856372833252
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 7 0.6926202774047852
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 8 0.6923041343688965
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 9 0.6921443343162537
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 10 0.6920986175537109
# forward call
# ------------------------------
# 정확도 tensor(0.7500)
# 11 0.6919872760772705
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 12 0.6917569637298584
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 13 0.6915076971054077
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 14 0.69133460521698
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 15 0.6912170648574829
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 16 0.6910637021064758
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 17 0.6908363103866577
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 18 0.6905826330184937
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 19 0.6903603076934814
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 20 0.6901659965515137
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 21 0.6899479627609253
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 22 0.6896764636039734
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 23 0.6893736124038696
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 24 0.689074695110321
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 25 0.6887813806533813
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 26 0.6884629130363464
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 27 0.6880974769592285
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 28 0.6876952648162842
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 29 0.68727707862854
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 30 0.6868445873260498
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 31 0.6863787174224854
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 32 0.6858645081520081
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 33 0.6853066086769104
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 34 0.6847161650657654
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 35 0.6840928792953491
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 36 0.683423638343811
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 37 0.6826986074447632
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 38 0.6819196343421936
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 39 0.6810922622680664
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 40 0.6802142262458801
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 41 0.6792765259742737
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 42 0.6782724857330322
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 43 0.677202582359314
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 44 0.6760684847831726
# forward call
# ------------------------------
# 정확도 tensor(0.5000)
# 45 0.6748672127723694
# forward call
# ------------------------------
# 정확도 tensor(0.7500)
# 46 0.6735923290252686
